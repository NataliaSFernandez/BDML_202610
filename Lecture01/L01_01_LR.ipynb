# %% [markdown]
# <div >
# <img src = "../banner.jpg" />
# </div>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ignaciomsarmiento/BDML_202610/blob/main/Lecture01/L01_01_LR.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Predicción con modelos lineales
#
# Nuestro objetivo  es construir un modelo predictivo de salario
#
# $$
# w = f(X) + u
# $$
#
# Donde w es el salario y X es una matriz que incluye posibles variables/predictores explicativas (ej. educación, edad, educación de los padres, habilidad cognitiva, etc.).
#
# Un ejemplo de modelo predictivo es un modelo lineal en parámetros:
#
# $$
# ln(w)  = \beta_0 + \beta_1 X_1 + \dots + \beta_p X_p + u
# $$
#
# donde $ln(w)$ es el logaritmo del salario.
#
# Para ilustrar, usaré una muestra del NLSY97. El NLSY97 es una muestra representativa a nivel nacional de 8.984 hombres y mujeres nacidos entre 1980 y 1984 y que vivían en los Estados Unidos durante la encuesta inicial de 1997. Los participantes tenían entre 12 y 16 años al 31 de diciembre de 1996. Las entrevistas se realizaron anualmente desde 1997 hasta 2011 y cada dos años desde entonces.
#
# Carguemos los paquetes.

# %%
# install.packages("pacman") #Correr esta linea en Google Colab

# %%
# Cargamos los paquetes

require("pacman")

p_load("tidyverse","stargazer")
# Out:
# Loading required package: pacman
# The downloaded binary packages are in
# 	/var/folders/lp/bhbhb__n1_z91_rjfqljxcdc0000gn/T//RtmpIJLKwe/downloaded_packages
# stargazer installed

# %% [markdown]
# Cargamos la base:

# %%
nlsy <- read_csv('https://raw.githubusercontent.com/ignaciomsarmiento/datasets/main/nlsy97.csv')

#Housekeeping
nlsy <- nlsy  %>%   drop_na(educ) #dropea los valores faltantes (NA)
# Out:
# Rows: 1266 Columns: 994
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (994): lnw_2016, educ, black, hispanic, other, exp, afqt, mom_educ, dad_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(nlsy)
# Out:
#   lnw_2016 educ black hispanic other exp afqt   mom_educ dad_educ yhea_100_1997
# 1 4.076898 16   0     0        0     11  7.0724 12       12       3
# 2 3.294138  9   0     0        0     19  4.7481  9       10       2
# 3 2.830896  9   0     1        0     22  1.1987 12        9       3
# 4 4.306459 16   0     0        0     13  8.9321 16       18       2
# 5 5.991465 16   0     1        0     15  2.2618 16       16       1
# 6 4.711924 16   0     0        0     14  8.9502 18       20       1
#   ⋯ _XPexp_13 _XPexp_14 _XPexp_16 _XPexp_17 _XPexp_18 _XPexp_19 _XPexp_20
# 1 ⋯ 0         0         0         0         0         0         0
# 2 ⋯ 0         0         0         0         0         1         0
# 3 ⋯ 0         0         0         0         0         0         0
# 4 ⋯ 1         0         0         0         0         0         0
# 5 ⋯ 0         0         0         0         0         0         0
# 6 ⋯ 0         1         0         0         0         0         0
#   _XPexp_21 _XPexp_22 _XPexp_23
# 1 0         0         0
# 2 0         0         0
# 3 0         1         0
# 4 0         0         0
# 5 0         0         0
# 6 0         0         0

# %% [markdown]
# ## Regresión Lineal

# %%
reg1 <- lm(lnw_2016~educ,   data = nlsy)

# %%
stargazer(reg1,type="text") #Similar en stata: outreg2
# Out:
# ===============================================
#                         Dependent variable:
#                     ---------------------------
#                              lnw_2016
# -----------------------------------------------
# educ                         0.077***
#                               (0.008)
#
# Constant                     2.003***
#                               (0.119)
#
# -----------------------------------------------
# Observations                   1,266
# R2                             0.067
# Adjusted R2                    0.066
# Residual Std. Error      0.840 (df = 1264)
# F Statistic          90.128*** (df = 1; 1264)
# ===============================================
# Note:               *p<0.1; **p<0.05; ***p<0.01

# %% [markdown]
# ## Predicción
#
# $$
# \hat{y} = \hat{\beta}_0 +  \hat{\beta}_1 educ
# $$

# %%
reg1$coef
# Out:
# (Intercept)        educ
#  2.00307383  0.07732004

# %%
reg1$coef[1]
# Out:
# (Intercept)
#    2.003074

# %%
reg1$coef[1]+reg1$coef[2]*16
# Out:
# (Intercept)
#    3.240194

# %%
exp(reg1$coef[1]+reg1$coef[2]*16)
# Out:
# (Intercept)
#    25.53869

# %% [markdown]
# ## Modelando $E(y|X)$

# %%
#predict me simplifica hacer la operación X\hat{\beta}

nlsy <- nlsy  %>% mutate(yhat=predict(reg1)) #con la función mutate


# Voy a calcular E(y|X=x) y E(\hat(y)| X=x)

summ <- nlsy %>%  
  group_by(
    educ
  ) %>%  
  summarize(
    mean_y = mean(lnw_2016),
    yhat_reg = mean(yhat), .groups="drop"
  )

# %%
# graficamos
ggplot(summ) + 
  geom_point(
    aes(x = educ, y = mean_y),
    color = "blue", size = 3
  ) + 
  geom_line(
    aes(x = educ, y = yhat_reg), 
    color = "green", linewidth = 1.5
  ) + 
  labs(
    title = "Log Salarios por Años de Educación",
    x = "Años de Educación",
    y = "Log Salarios"
  ) +
  theme_bw()
# Out:
# plot without title

# %% [markdown]
# Vamos a constuir regresores polinomiales de forma tal de tener reglas de predicción más flexibles y potencialmente mejores.

# %%
#Polinomios de educación

nlsy <- nlsy  %>% mutate(educ2=educ^2,
                         educ3=educ^3,
                         educ4=educ^4,
                         educ5=educ^5,
                         educ6=educ^6,
                         educ7=educ^7,
                         educ8=educ^8
                        )

# %%
head(nlsy)
# Out:
#   lnw_2016 educ black hispanic other exp afqt   mom_educ dad_educ yhea_100_1997
# 1 4.076898 16   0     0        0     11  7.0724 12       12       3
# 2 3.294138  9   0     0        0     19  4.7481  9       10       2
# 3 2.830896  9   0     1        0     22  1.1987 12        9       3
# 4 4.306459 16   0     0        0     13  8.9321 16       18       2
# 5 5.991465 16   0     1        0     15  2.2618 16       16       1
# 6 4.711924 16   0     0        0     14  8.9502 18       20       1
#   ⋯ _XPexp_22 _XPexp_23 yhat     educ2 educ3 educ4 educ5   educ6    educ7
# 1 ⋯ 0         0         3.240194 256   4096  65536 1048576 16777216 268435456
# 2 ⋯ 0         0         2.698954  81    729   6561   59049   531441   4782969
# 3 ⋯ 1         0         2.698954  81    729   6561   59049   531441   4782969
# 4 ⋯ 0         0         3.240194 256   4096  65536 1048576 16777216 268435456
# 5 ⋯ 0         0         3.240194 256   4096  65536 1048576 16777216 268435456
# 6 ⋯ 0         0         3.240194 256   4096  65536 1048576 16777216 268435456
#   educ8
# 1 4294967296
# 2   43046721
# 3   43046721
# 4 4294967296
# 5 4294967296
# 6 4294967296

# %% [markdown]
#  Corremos la regresión

# %%
reg2 <- lm(lnw_2016~educ+ educ2 + educ3 + educ4 + educ5 + educ6 + educ7 + 
    educ8 ,   data = nlsy)

# %%
stargazer(reg1,reg2,type="text") #Similar en stata: outreg2
# Out:
# =====================================================================
#                                    Dependent variable:
#                     -------------------------------------------------
#                                         lnw_2016
#                               (1)                      (2)
# ---------------------------------------------------------------------
# educ                        0.077***                3,798.831*
#                             (0.008)                (2,157.819)
#
# educ2                                              -1,040.673*
#                                                     (578.718)
#
# educ3                                                160.193*
#                                                      (87.500)
#
# educ4                                                -15.163*
#                                                      (8.161)
#
# educ5                                                 0.904*
#                                                      (0.481)
#
# educ6                                                -0.033*
#                                                      (0.018)
#
# educ7                                                 0.001*
#                                                      (0.0004)
#
# educ8                                               -0.00001*
#                                                     (0.00000)
#
# Constant                    2.003***               -5,960.604*
#                             (0.119)                (3,471.172)
#
# ---------------------------------------------------------------------
# Observations                 1,266                    1,266
# R2                           0.067                    0.075
# Adjusted R2                  0.066                    0.069
# Residual Std. Error    0.840 (df = 1264)        0.839 (df = 1257)
# F Statistic         90.128*** (df = 1; 1264) 12.682*** (df = 8; 1257)
# =====================================================================
# Note:                                     *p<0.1; **p<0.05; ***p<0.01

# %%
#predict me simplifica hacer la operación X\hat{\beta}

nlsy <- nlsy  %>% mutate(yhat_2=predict(reg2)) #con la función mutate

# %%
head(nlsy)
# Out:
#   lnw_2016 educ black hispanic other exp afqt   mom_educ dad_educ yhea_100_1997
# 1 4.076898 16   0     0        0     11  7.0724 12       12       3
# 2 3.294138  9   0     0        0     19  4.7481  9       10       2
# 3 2.830896  9   0     1        0     22  1.1987 12        9       3
# 4 4.306459 16   0     0        0     13  8.9321 16       18       2
# 5 5.991465 16   0     1        0     15  2.2618 16       16       1
# 6 4.711924 16   0     0        0     14  8.9502 18       20       1
#   ⋯ _XPexp_23 yhat     educ2 educ3 educ4 educ5   educ6    educ7     educ8
# 1 ⋯ 0         3.240194 256   4096  65536 1048576 16777216 268435456 4294967296
# 2 ⋯ 0         2.698954  81    729   6561   59049   531441   4782969   43046721
# 3 ⋯ 0         2.698954  81    729   6561   59049   531441   4782969   43046721
# 4 ⋯ 0         3.240194 256   4096  65536 1048576 16777216 268435456 4294967296
# 5 ⋯ 0         3.240194 256   4096  65536 1048576 16777216 268435456 4294967296
# 6 ⋯ 0         3.240194 256   4096  65536 1048576 16777216 268435456 4294967296
#   yhat_2
# 1 3.311502
# 2 2.661006
# 3 2.661006
# 4 3.311502
# 5 3.311502
# 6 3.311502

# %%
# Voy a calcular E(y|X=x) y E(\hat(y)| X=x)

summ <- nlsy %>%  
  group_by(
    educ, educ2, educ3, educ4, educ5, 
    educ6, educ7, educ8
  ) %>%  
  summarize(
    mean_y = mean(lnw_2016),
      yhat_reg = mean(yhat), 
    yhat_reg_2 = mean(yhat_2), .groups="drop"
  )

# %%
head(summ)
# Out:
#   educ educ2 educ3 educ4 educ5  educ6   educ7    educ8     mean_y   yhat_reg
# 1  8    64    512   4096  32768  262144  2097152  16777216 2.893439 2.621634
# 2  9    81    729   6561  59049  531441  4782969  43046721 2.660140 2.698954
# 3 10   100   1000  10000 100000 1000000 10000000 100000000 2.592467 2.776274
# 4 11   121   1331  14641 161051 1771561 19487171 214358881 2.862028 2.853594
# 5 12   144   1728  20736 248832 2985984 35831808 429981696 2.948959 2.930914
# 6 13   169   2197  28561 371293 4826809 62748517 815730721 3.080338 3.008234
#   yhat_reg_2
# 1 2.893126
# 2 2.661006
# 3 2.597356
# 4 2.824300
# 5 2.972449
# 6 2.969692

# %%
# graficamos
ggplot(summ) + 
  geom_point(
    aes(x = educ, y = mean_y),
    color = "blue", size = 3
  ) + 
  geom_line(
    aes(x = educ, y = yhat_reg), 
    color = "green", linewidth = 0.5
  ) +
geom_line(
    aes(x = educ, y = yhat_reg_2), 
    color = "orange", linewidth = 1.5
  )+ 
  labs(
    title = "Log Salarios por Años de Educación",
    x = "Años de Educación",
    y = "Log Salarios"
  ) +
  theme_bw()
# Out:
# plot without title

# %% [markdown]
# Como podemos ver, este modelo flexible captura muy bien patrones complejos.
#
# Incluyendo un conjunto lo suficientemente rico de transformaciones, las predicciones de OLS producirán estimaciones del predictor ideal: la función de expectativa condicional.
